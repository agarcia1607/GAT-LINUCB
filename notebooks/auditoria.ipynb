# %%
import os
from pathlib import Path

os.chdir("../")

# %% [markdown]
# # Download Prices

# %%
from src.downloadPrices import DownloadPrices

dp = DownloadPrices(verbose=True)

# %% [markdown]
# ## get_tickers

# %%
tickers = dp._get_tickers()
tickers = tickers[:5]
tickers
# Out:
# 	[INFO] Fetching tickers from: https://en.wikipedia.org/wiki/List_of_S%26P_500_companies
# 	[INFO] Tickers saved to: artifacts\tickers\tickers.json
# 	[INFO] Parsed 503 tickers.
# ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN']

# %% [markdown]
# ## download tickers

# %%
dp._download_tickers(tickers)
# Out:
# 	[INFO] Downloading 5 tickers from 2015-01-01...
# [*********************100%***********************]  5 of 5 completed
# 	[INFO] Download complete. Dates: 2015-01-02 -> 2026-01-08 | rows=13855
# 	[INFO] Saved to: artifacts\tickers\prices.parquet
# True

# %%
import pandas as pd

df = pd.read_parquet(Path(os.getenv("TICKERS_DIR")) / Path("prices.parquet"))
print(df.head())
# Out:
#            TICKER  ADJ_CLOSE       CLOSE        HIGH         LOW        OPEN  \
# DATE
# 2015-01-02   ABBV  42.091419   65.889999   66.400002   65.440002   65.440002
# 2015-01-02    ABT  36.418674   44.900002   45.450001   44.639999   45.250000
# 2015-01-02    ACN  74.252609   88.839996   90.089996   88.430000   89.669998
# 2015-01-02    AOS  23.472965   28.004999   28.415001   27.775000   28.309999
# 2015-01-02    MMM  96.108528  137.173920  138.026749  136.061874  137.717392
#
#                VOLUME
# DATE
# 2015-01-02  5086100.0
# 2015-01-02  3216600.0
# 2015-01-02  2021300.0
# 2015-01-02  1540200.0
# 2015-01-02  2531214.0

# %% [markdown]
# Se descarga correctamente

# %% [markdown]
# ## main

# %%
dp.main()
# Out:
# [START] Download prices
# 	[INFO] Fetching tickers from: https://en.wikipedia.org/wiki/List_of_S%26P_500_companies
# 	[INFO] Tickers saved to: artifacts\tickers\tickers.json
# 	[INFO] Parsed 503 tickers.
# 	[DONE] get_tickers()
# 	[INFO] Downloading 503 tickers from 2015-01-01...
# [**********************77%************           ]  386 of 503 completed$BRK.B: possibly delisted; no timezone found
# [**********************93%********************   ]  467 of 503 completed$BF.B: possibly delisted; no price data found  (1d 2015-01-01 -> 2026-01-08)
# [*********************100%***********************]  503 of 503 completed
#
# 2 Failed downloads:
# ['BRK.B']: possibly delisted; no timezone found
# ['BF.B']: possibly delisted; no price data found  (1d 2015-01-01 -> 2026-01-08)
# 	[INFO] Download complete. Dates: 2015-01-02 -> 2026-01-08 | rows=1393813
# 	[INFO] Saved to: artifacts\tickers\prices.parquet
# 	[DONE] download_tickers()
# [FINISHED] Download prices
