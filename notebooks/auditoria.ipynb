# %%
import os
from pathlib import Path

os.chdir("../")

# %% [markdown]
# # Download Prices

# %%
from src.downloadPrices import DownloadPrices

dp = DownloadPrices(verbose=True)

# %% [markdown]
# ## get_tickers

# %%
tickers = dp._get_tickers()
tickers = tickers[:5]
tickers
# Out:
# 	[INFO] Fetching tickers from: https://en.wikipedia.org/wiki/List_of_S%26P_500_companies
# 	[INFO] Tickers saved to: artifacts\tickers\tickers.json
# 	[INFO] Parsed 503 tickers.
# ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN']

# %% [markdown]
# ## download tickers

# %%
dp._download_tickers(tickers)
# Out:
# 	[INFO] Downloading 5 tickers from 2015-01-01...
# [*********************100%***********************]  5 of 5 completed
# 	[INFO] Download complete. Dates: 2015-01-01 -> 2026-01-01 | rows=2875
# 	[INFO] Saved to: artifacts\tickers\prices.parquet
# True

# %%
import pandas as pd

df = pd.read_parquet(Path(os.getenv("TICKERS_DIR")) / Path("prices.parquet"))
df = df[df.TICKER == "MMM"]
print(df.head())
# Out:
#            TICKER  ADJ_CLOSE       CLOSE        HIGH         LOW        OPEN  \
# DATE
# 2015-01-01    MMM  93.612999  133.612045  138.026749  131.889633  137.717392
# 2015-01-08    MMM  93.636414  133.645493  137.441467  132.525085  134.322739
# 2015-01-15    MMM  95.218124  135.903015  136.622070  133.018402  134.523407
# 2015-01-22    MMM  96.038239  137.073578  139.272568  134.565216  136.505020
# 2015-01-29    MMM  96.547890  137.801010  138.954849  134.523407  137.182281
#
#                 VOLUME
# DATE
# 2015-01-01  14857429.0
# 2015-01-08  14779211.0
# 2015-01-15   9467536.0
# 2015-01-22  18888429.0
# 2015-01-29  16247182.0

# %% [markdown]
# Se descarga correctamente

# %% [markdown]
# ## main

# %%
DownloadPrices(verbose=True).main()
# Out:
# [START] Download prices
# 	[RUNNING] get_tickers()
# 		[INFO] Fetching tickers from: https://en.wikipedia.org/wiki/List_of_S%26P_500_companies
# 		[INFO] Tickers saved to: artifacts\tickers\tickers.json
# 		[INFO] Parsed 503 tickers.
# 	[DONE] get_tickers()
# 	[RUNNING] download_tickers()
# 		[INFO] Downloading 503 tickers from 2015-01-01...
# [***                    6%                       ]  29 of 503 completed$BRK.B: possibly delisted; no timezone found
# [**********************60%****                   ]  304 of 503 completed$BF.B: possibly delisted; no price data found  (1wk 2015-01-01 -> 2026-01-08)
# [*********************100%***********************]  503 of 503 completed
#
# 4 Failed downloads:
# ['BRK.B']: possibly delisted; no timezone found
# ['BF.B']: possibly delisted; no price data found  (1wk 2015-01-01 -> 2026-01-08)
# ['DRI', 'WEC']: TypeError("'NoneType' object is not subscriptable")
# 		[INFO] Download complete. Dates: 2015-01-01 -> 2026-01-05 | rows=572414
# 		[INFO] Saved to: artifacts\tickers\prices.parquet
# 	[DONE] download_tickers()
# [FINISHED] Download prices
